# %%
import pandas as pd
import json
from mapping import get_technology

EXCLUDED_DIRS = ("docs/", "data/", "lib/", "benchmark/", "annotations/", "examples/")

df = pd.read_csv("../data/technology_composition/project_technologies.csv")

df_sample = df.sample(20)

df_sample.to_csv("../data/technology_composition/project_technologies_sample.csv", index=False)

# %%
project_sample = df_sample["project"].tolist()

file_type_files = []

for project in project_sample:
    project_file = f"../data/projects_last_commit/{project}_last_commit.json"
    with open(project_file, "r", encoding="utf-8") as f:
        data = json.load(f)
        commit_data = data["latest_commit_data"]["network_data"]

        for config_file in commit_data["config_file_data"]:
            if config_file["file_path"].startswith(EXCLUDED_DIRS):
                continue

            if config_file["concept"] in ["json", "yaml", "toml", "configparser"]:
                tech = get_technology(config_file["file_path"])
                if not tech:
                    file_type_files.append(config_file["file_path"])

# %% [markdown]
# First iteration: 21
# Second iteration:

# %%
print(file_type_files)
# Out:
# ['.github/codeql/codeql-config.yml', '.mocharc.yml', 'examples/schema/storing-schemas-as-json/schema.json', 'lgtm.yml', 'hugoreleaser.yaml', 'snap/snapcraft.yaml', '.github/mypy-primer-ty.toml', '.pre-commit-config.yaml', '_typos.toml', 'assets/badge/format.json', 'assets/badge/v0.json', 'assets/badge/v1.json', 'assets/badge/v2.json', 'crates/ruff_python_ast/ast.toml', 'dist-workspace.toml', 'mkdocs.insiders.yml', 'mkdocs.public.yml', 'mkdocs.template.yml', 'playground/api/wrangler.toml', 'ruff.schema.json', 'scripts/benchmarks/graph-spec.json', 'ty.schema.json', '.changeset/config.json', '.config/demos.json', '.github/configs/semgrep_rules.yaml', '.github/filters.json', 'client/python/gradio_client/types.json', 'demo/image_classifier/files/imagenet_labels.json', 'demo/image_classifier_2/files/imagenet_labels.json', 'demo/mini_leaderboard/assets/leaderboard_data.json', 'gradio/cli/commands/components/files/pyproject_.toml', 'gradio/cli/commands/deploy_space_action.yaml', 'js/_website/src/lib/assets/tweets.json', 'js/_website/src/routes/version.json', 'js/core/src/lang/ar.json', 'js/core/src/lang/ca.json', 'js/core/src/lang/ckb.json', 'js/core/src/lang/de.json', 'js/core/src/lang/en.json', 'js/core/src/lang/es.json', 'js/core/src/lang/eu.json', 'js/core/src/lang/fa.json', 'js/core/src/lang/fi.json', 'js/core/src/lang/fr.json', 'js/core/src/lang/he.json', 'js/core/src/lang/hi.json', 'js/core/src/lang/ja.json', 'js/core/src/lang/ko.json', 'js/core/src/lang/lt.json', 'js/core/src/lang/nb.json', 'js/core/src/lang/nl.json', 'js/core/src/lang/pl.json', 'js/core/src/lang/pt-BR.json', 'js/core/src/lang/pt.json', 'js/core/src/lang/ro.json', 'js/core/src/lang/ru.json', 'js/core/src/lang/sv.json', 'js/core/src/lang/ta.json', 'js/core/src/lang/th.json', 'js/core/src/lang/tr.json', 'js/core/src/lang/uk.json', 'js/core/src/lang/ur.json', 'js/core/src/lang/uz.json', 'js/core/src/lang/zh-CN.json', 'js/core/src/lang/zh-TW.json', '.pre-commit-config.yaml', '.readthedocs.yaml', '.releaserc.yml', 'codebeaver.yml', 'examples/extras/example.yml', 'examples/json_scraper_graph/ollama/inputs/example.json', 'examples/json_scraper_graph/openai/inputs/example.json', 'readthedocs.yml', '.devcontainer/compose.yaml', 'actionview/lib/action_view/locale/en.yml', 'activemodel/lib/active_model/locale/en.yml', 'activerecord/lib/active_record/locale/en.yml', 'activesupport/lib/active_support/locale/en.yml', 'guides/source/documents.yaml', 'railties/lib/rails/generators/rails/app/templates/config/locales/en.yml', 'railties/lib/rails/generators/rails/app/templates/github/dependabot.yml', 'railties/lib/rails/generators/rails/plugin/templates/github/dependabot.yml', 'compiler/crates/relay-compiler/relay-compiler-config-schema.json', 'crowdin.yaml', 'website/versioned_sidebars/version-classic-sidebars.json', 'website/versioned_sidebars/version-experimental-sidebars.json', 'website/versioned_sidebars/version-v13.0.0-sidebars.json', 'website/versioned_sidebars/version-v14.0.0-sidebars.json', 'website/versioned_sidebars/version-v15.0.0-sidebars.json', 'website/versioned_sidebars/version-v16.0.0-sidebars.json', 'website/versioned_sidebars/version-v17.0.0-sidebars.json', 'website/versioned_sidebars/version-v18.0.0-sidebars.json', 'website/versioned_sidebars/version-v19.0.0-sidebars.json', 'website/versioned_sidebars/version-v20.0.0-sidebars.json', 'website/versions.json', 'appimage/AppImageBuilder-aarch64.yml', 'appimage/AppImageBuilder-x86_64.yml', 'flatpak/rustdesk.json', 'flutter/analysis_options.yaml', 'flutter/ios/Runner/Assets.xcassets/AppIcon.appiconset/Contents.json', 'flutter/ios/Runner/Assets.xcassets/LaunchImage.imageset/Contents.json', 'res/vcpkg/aom/vcpkg.json', 'res/vcpkg/ffmpeg/vcpkg.json', 'res/vcpkg/libvpx/vcpkg.json', 'res/vcpkg/libyuv/vcpkg.json', 'res/vcpkg/mfx-dispatch/vcpkg.json', 'res/vcpkg/opus/vcpkg.json', 'vcpkg.json', '.github/DISCUSSION_TEMPLATE/questions.yml', '.pre-commit-config.yaml', '.github/workflows/config/jax/keras.json', '.github/workflo ...

# %%
from mapping import get_technology

tests = [
    ("packages/vite/tsconfig.base.json", "tsconfig"),
    ("ci/k8s/jobset.yaml", "kubernetes"),
    ("docker-compose.server.example.yml", "docker-compose"),
    ("js/tsconfig.eslint.json", "eslint"),
    (".github/ISSUE_TEMPLATE/bug_report.yaml", "github"),
    ("docs/reference/docker_compose_run.yaml", "docker-compose"),
    ("apps/api/pnpm-lock.yaml", "pnpm"),
    ("apps/redis/fly.toml", "flyio"),
    ("apps/ui/ingestion-ui/package-lock.json", "npm"),
    ("docker-compose.yaml", "docker-compose"),
    ("examples/kubernetes/cluster-install/api.yaml", "kubernetes"),
    (".devcontainer/devcontainer.json", "devcontainer"),
    ( ".eslintrc.json", "eslint"),
    (".github/ISSUE_TEMPLATE/bug_report.yml", "github"),
    (".github/actions/build-electron/action.yml", "github-actions"),
    (".github/dependabot.yml", "dependabot"),
    (".github/ISSUE_TEMPLATE/config.yml", "github"),
    ("apollo-adminservice/src/main/resources/application-zookeeper-discovery.properties", "spring")
]

results = []

for filename, expected in tests:
    actual = get_technology(filename)
    success = (actual == expected)
    results.append((filename, expected, actual, success))

results
# Out:
# [('packages/vite/tsconfig.base.json', 'tsconfig', 'tsconfig', True),
#  ('ci/k8s/jobset.yaml', 'kubernetes', 'kubernetes', True),
#  ('docker-compose.server.example.yml',
#   'docker-compose',
#   'docker-compose',
#   True),
#  ('js/tsconfig.eslint.json', 'eslint', 'eslint', True),
#  ('.github/ISSUE_TEMPLATE/bug_report.yaml', 'github', 'github', True),
#  ('docs/reference/docker_compose_run.yaml',
#   'docker-compose',
#   'docker-compose',
#   True),
#  ('apps/api/pnpm-lock.yaml', 'pnpm', 'pnpm', True),
#  ('apps/redis/fly.toml', 'flyio', 'flyio', True),
#  ('apps/ui/ingestion-ui/package-lock.json', 'npm', 'npm', True),
#  ('docker-compose.yaml', 'docker-compose', 'docker-compose', True),
#  ('examples/kubernetes/cluster-install/api.yaml',
#   'kubernetes',
#   'kubernetes',
#   True),
#  ('.devcontainer/devcontainer.json', 'devcontainer', 'devcontainer', True),
#  ('.eslintrc.json', 'eslint', 'eslint', True),
#  ('.github/ISSUE_TEMPLATE/bug_report.yml', 'github', 'github', True),
#  ('.github/actions/build-electron/action.yml',
#   'github-actions',
#   'github-actions',
#   True),
#  ('.github/dependabot.yml', 'dependabot', 'dependabot', True),
#  ('.github/ISSUE_TEMPLATE/config.yml', 'github', 'github', True),
#  ('apollo-adminservice/src/main/resources/application-zookeeper-discovery.properties',
#   'spring',
#   'spring',
#   True)]
