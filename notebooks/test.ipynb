# %% [markdown]
# **Create Last Commit File**

# %%
import json
import os
import glob
import re

project_dirs = os.listdir("../data/projects/")

def get_batch_number(path):
    match = re.search(r'batch_(\d+)\.json$', path)
    return int(match.group(1)) if match else -1


for dir in project_dirs:
    print(f"Processing directory: {dir}")
    project_files = sorted(glob.glob(f"../data/projects/{dir}/*.json"))

    project_name = project_files[0].split("/")[-2]
    output_file = f"../data/projects_last_commit/{project_name}_last_commit.json"
    if os.path.exists(output_file):
        print(f"Output file {output_file} already exists. Skipping...")
        continue
        
    if len(project_files) == 1:
        project_file = project_files[0]
    else:
        project_file = max(project_files, key=get_batch_number)

    try:
        with open(project_file, 'r') as f:
            data = json.load(f)
            
        latest_commit = data["commit_data"][-1]
    
        # Check if latest commit is indeed the latest
        if not latest_commit["is_latest_commit"]:
            raise ValueError("Latest commit is not latest according to is_latest_commit flag")
        
        # Check if latest commit  contains data
        if latest_commit["is_latest_commit"]:
            if not latest_commit["network_data"]:
                raise ValueError("Latest commit's network data is empty")

        del data["commit_data"]

        data["latest_commit_data"] = latest_commit

        with open(output_file, 'w') as f:
            json.dump(data, f, indent=4)
            
    except Exception as e:
        print(f"Error processing {project_file}: {e}")
        continue

# %% [markdown]
# **Check number of projects**

# %%
import glob

projects = glob.glob("../data/projects/*json")
project_with_batches = os.listdir("../data/projects_with_batches")

project_lc_files = glob.glob("../data/projects_last_commit/*json")

print("Length of projects: ", len(projects))
print("Length of project_with_batches: ", len(project_with_batches))
print("Total projects; ", len(projects) + len(project_with_batches))
print("Missing projects: ", 1148 - (len(projects) + len(project_with_batches)))
print("Length of project_lc_files: ", len(project_lc_files))
# Out:
# Length of projects:  959
# Length of project_with_batches:  33
# Total projects;  992
# Missing projects:  156
# Length of project_lc_files:  929

# %%
import os
import glob
import shutil

# Pfad zu den Projektdateien
projects_dir = "../data/projects/"
project_files = glob.glob(os.path.join(projects_dir, "*.json"))

print(f"Gefundene Projektdateien: {len(project_files)}")

for project_file in project_files:
    # Extrahiere den Projektnamen aus dem Dateinamen (ohne .json)
    project_name = os.path.basename(project_file).replace(".json", "")
    
    # Erstelle den Ordnerpfad
    project_folder = os.path.join(projects_dir, project_name)
    
    print(f"Verarbeite: {project_name}")
    
    try:
        # Erstelle den Ordner, falls er nicht existiert
        os.makedirs(project_folder, exist_ok=True)
        
        # Zielpfad für die verschobene Datei
        destination = os.path.join(project_folder, os.path.basename(project_file))
        
        # Verschiebe die Datei
        shutil.move(project_file, destination)
        
        print(f"✓ {project_name}.json wurde nach {project_folder}/ verschoben")
        
    except Exception as e:
        print(f"✗ Fehler beim Verarbeiten von {project_name}: {e}")

print("Fertig!")
# Out:
# Gefundene Projektdateien: 965
# Verarbeite: mobx
# ✓ mobx.json wurde nach ../data/projects/mobx/ verschoben
# Verarbeite: winget-cli
# ✓ winget-cli.json wurde nach ../data/projects/winget-cli/ verschoben
# Verarbeite: googletest
# ✓ googletest.json wurde nach ../data/projects/googletest/ verschoben
# Verarbeite: you-get
# ✓ you-get.json wurde nach ../data/projects/you-get/ verschoben
# Verarbeite: jsoncrack.com
# ✓ jsoncrack.com.json wurde nach ../data/projects/jsoncrack.com/ verschoben
# Verarbeite: electron
# ✓ electron.json wurde nach ../data/projects/electron/ verschoben
# Verarbeite: openssl
# ✓ openssl.json wurde nach ../data/projects/openssl/ verschoben
# Verarbeite: homebrew-cask
# ✓ homebrew-cask.json wurde nach ../data/projects/homebrew-cask/ verschoben
# Verarbeite: AnotherRedisDesktopManager
# ✓ AnotherRedisDesktopManager.json wurde nach ../data/projects/AnotherRedisDesktopManager/ verschoben
# Verarbeite: trufflehog
# ✓ trufflehog.json wurde nach ../data/projects/trufflehog/ verschoben
# Verarbeite: k3s
# ✓ k3s.json wurde nach ../data/projects/k3s/ verschoben
# Verarbeite: ace
# ✓ ace.json wurde nach ../data/projects/ace/ verschoben
# Verarbeite: gitbook
# ✓ gitbook.json wurde nach ../data/projects/gitbook/ verschoben
# Verarbeite: beekeeper-studio
# ✓ beekeeper-studio.json wurde nach ../data/projects/beekeeper-studio/ verschoben
# Verarbeite: Ventoy
# ✓ Ventoy.json wurde nach ../data/projects/Ventoy/ verschoben
# Verarbeite: harbor
# ✓ harbor.json wurde nach ../data/projects/harbor/ verschoben
# Verarbeite: xterm.js
# ✓ xterm.js.json wurde nach ../data/projects/xterm.js/ verschoben
# Verarbeite: dimsemenov_PhotoSwipe
# ✓ dimsemenov_PhotoSwipe.json wurde nach ../data/projects/dimsemenov_PhotoSwipe/ verschoben
# Verarbeite: LLaMA-Factory
# ✓ LLaMA-Factory.json wurde nach ../data/projects/LLaMA-Factory/ verschoben
# Verarbeite: void
# ✓ void.json wurde nach ../data/projects/void/ verschoben
# Verarbeite: opencv
# ✓ opencv.json wurde nach ../data/projects/opencv/ verschoben
# Verarbeite: spotube
# ✓ spotube.json wurde nach ../data/projects/spotube/ verschoben
# Verarbeite: vant-weapp
# ✓ vant-weapp.json wurde nach ../data/projects/vant-weapp/ verschoben
# Verarbeite: webpack
# ✓ webpack.json wurde nach ../data/projects/webpack/ verschoben
# Verarbeite: deskflow
# ✓ deskflow.json wurde nach ../data/projects/deskflow/ verschoben
# Verarbeite: dive
# ✓ dive.json wurde nach ../data/projects/dive/ verschoben
# Verarbeite: OpenAPI-Specification
# ✓ OpenAPI-Specification.json wurde nach ../data/projects/OpenAPI-Specification/ verschoben
# Verarbeite: Aerial
# ✓ Aerial.json wurde nach ../data/projects/Aerial/ verschoben
# Verarbeite: Xray-core
# ✓ Xray-core.json wurde nach ../data/projects/Xray-core/ verschoben
# Verarbeite: libuv
# ✓ libuv.json wurde nach ../data/projects/libuv/ verschoben
# Verarbeite: jq
# ✓ jq.json wurde nach ../data/projects/jq/ verschoben
# Verarbeite: MetaGPT
# ✓ MetaGPT.json wurde nach ../data/projects/MetaGPT/ verschoben
# Verarbeite: penpot
# ✓ penpot.json wurde nach ../data/projects/penpot/ verschoben
# Verarbeite: drawio-desktop
# ✓ drawio-desktop.json wurde nach ../data/projects/drawio-desktop/ verschoben
# Verarbeite: Jobs_Applier_AI_Agent_AIHawk
# ✓ Jobs_Applier_AI_Agent_AIHawk.json wurde nach ../data/projects/Jobs_Applier_AI_Agent_AIHawk/ verschoben
# Verarbeite: p5.js
# ✓ p5.js.json wurde nach ../data/projects/p5.js/ verschoben
# Verarbeite: docling
# ✓ docling.json wurde nach ../data/projects/docling/ verschoben
# Verarbeite: stats
# ✓ stats.json wurde nach ../data/projects/stats/ verschoben
# Verarbeite: distroless
# ✓ distroless.json wurde nach ../data/projects/distroless/ verschoben
# Verarbeite: plotly_dash
# ✓ plotly_dash.json wurde nach ../data/projects/plotly_dash/ verschoben
# Verarbeite: react-native-vector-icons
# ✓ react-native-vector-icons.json wurde nach ../data/projects/react-native-vector-icons/ verschoben
# Verarbeite: setup-ipsec-vpn
# ✓ setup-ipsec-vpn.json wurde nach ../data/projects/setup-ipsec-vpn/ verschoben
# Verarbeite: koodo-reader
# ✓ koodo-reader.json wurde nach ../data/projects/koodo-reader/ verschoben
# Verarbeite: retrofit
# ✓ retrofit.json wurde nach ../data/projects/retrofit/ verschoben
# Verarbeite: faas
# ✓ faas.json wurde nach ../data/projects/faas/ verschoben
# Verarbeite: flow
# ✓ flow.json wurde nach ../data/projects/flow/ verschoben
# Verarbeite: rich
# ✓ rich.json wurde nach ../data/projects/rich/ verschoben
# Verarbeite: dubbo
# ✓ dubbo.json wurde nach ../data/projects/dubbo/ verschoben
# Verarbeite: llamafile
# ✓ llamafile.json wurde nach ../data/projects/llamafile/ verschoben
# Verarbeite: paperless-ngx
# ✓ paperless-ngx.json wurde nach ../data/projects/paperless-ngx/ verschoben
# Verarbeite: windows
# ✓ windows.json wurde nach ../data/projects/windows/ verschoben
# Verarbeite: incubator-seata
# ✓ incubator-seata.json wurde nach ../data/projects/incubator-seata/ verschoben
# Verarbeite: cli
# ✓ cli.json wurde nach ../data/projects/cli/ verschoben
# Verarbeite: localstack
# ✓ localstack.json wurde nach ../data/projects/localstack/ verschoben
# Verarbeite: maui
# ✓ maui.json wurde nach ../data/projects/maui/ verschoben
# Verarbeite: fullcalendar
# ✓ fullcalendar.json wurde nach ../data/projects/fullcalendar/ verschoben
# Verarbeite: sops
# ✓ sops.json wurde nach ../data/projects/sops/ verschoben
# Verarbeite: simdjson
# ✓ simdjson.json wurde nach ../data/projects/simdjson/ verschoben
# Verarbeite: text-generation-webui
# ✓ text-generation-webui.json wurde nach ../data/projects/text-generation-webui/ verschoben
# Verarbeite: mermaid
# ✓ mermaid.json wurde nach ../data/projects/mermaid/ verschoben
# Verarbeite: fuel-core
# ✓ fuel-core.json wurde nach ../data/projects/fuel-core/ verschoben
# Verarbeite: GSAP
# ✓ GSAP.json wurde nach ../data/projects/GSAP/ verschoben
# Verarbeite: react-testing-library
# ✓ react-testing-library.json wurde nach ../data/projects/react-testing-library/ verschoben
# Verarbeite: eleventy
# ✓ eleventy.json wurde nach ../data/projects/eleventy/ verschoben
# Verarbeite: spring-framework
# ✓ spring-framework.json wurde nach ../data/projects/spring-framework/ verschoben
# Verarbeite: anoma
# ✓ anoma.json wurde nach ../data/projects/anoma/ verschoben
# Verarbeite: minio
# ✓ minio.json wurde nach ../data/projects/minio/ verschoben
# Verarbeite: conductor
# ✓ conductor.json wurde nach ../data/projects/conductor/ verschoben
# Verarbeite: FlClash
# ✓ FlClash.json wurde nach ../data/projects/FlClash/ verschoben
# Verarbeite: pandas-ai
# ✓ pandas-ai.json wurde nach ../data/projects/pandas-ai/ verschoben
# Verarbeite: Files
# ✓ Files.json wurde nach ../data/projects/Files/ verschoben
# Verarbeite: tabby
# ✓ tabby.json wurde nach ../data/projects/tabby/ verschoben
# Verarbeite: ingress-nginx
# ✓ ingress-nginx.json wurde nach ../data/projects/ingress-nginx/ verschoben
# Verarbeite: fastify
# ✓ fastify.json wurde nach ../data/projects/fastify/ verschoben
# Verarbeite: syncthing
# ✓ syncthing.json wurde nach ../data/projects/syncthing/ verschoben
# Verarbeite: simple-icons
# ✓ simple-icons.json wurde nach ../data/projects/simple-icons/ verschoben
# Verarbeite: vuetify
# ✓ vuetify.json wurde nach ../data/projects/vuetify/ verschoben
# Verarbeite: notepad-plus-plus
# ✓ notepad-plus-plus.json wurde nach ../data/projects/notepad-plus-plus/ verschoben
# Verarbeite: parcel
# ✓ parcel.json wurde nach ../data/projects/parcel/ verschoben
# Verarbeite: Chat2DB
# ✓ Chat2DB.json wurde nach ../data/projects/Chat2DB/ verschoben
# Verarbeite: sst
# ✓ sst.json wurde nach ../data/projects/sst/ verschoben
# Verarbeite: jekyll
# ✓ jekyll.json wurde nach ../data/projects/jekyll/ verschoben
# Verarbeite: plane
# ✓ plane.json wurde nach ../data/projects/plane/ verschoben
# Verarbeite: typst
# ✓ typst.json wurde nach ../data/projects/typst/ verschoben
# Verarbeite: netbox
# ✓ netbox.json wurde nach ../data/projects/netbox/ verschoben
# Verarbeite: react
# ✓ react.json wurde nach ../data/projects/react/ verschoben
# Verarbeite: cmder
# ✓ cmder.json wurde nach ../data/projects/cmder/ verschoben
# Verarbeite: Genesis
# ✓ Genesis.json wurde nach ../data/projects/Genesis/ verschoben
# Verarbeite: haystack
# ✓ haystack.json wurde nach ../data/projects/haystack/ verschoben
# Verarbeite: bruno
# ✓ bruno.json wurde nach ../data/projects/bruno/ verschoben
# Verarbeite: react-navigation
# ✓ react-navigation.json wurde nach ../data/projects/react-navigation/ verschoben
# Verarbeite: postgres
# ✓ postgres.json wurde nach ../data/projects/postgres/ verschoben
# Verarbeite: gitui
# ✓ gitui.json wurde nach ../data/projects/gitui/ verschoben
# Verarbeite: goreplay
# ✓ goreplay.json wurde nach ../data/projects/goreplay/ verschoben
# Verarbeite: Sortable
# ✓ Sortable.json wurde nach ../data/projects/Sortable/ verschoben
# Verarbeite: cloc
# ✓ cloc.json wurde nach ../data/projects/cloc/ verschoben
# Verarbeite: polars
# ✓ polars.json wurde nach ../data/projects/polars/ verschoben
# Verarbeite: fish-speech
# ✓ fish-speech.json wurde nach ../data/projects/fish-speech/ verschoben
# Verarbeite: ohmyzsh
# ✓ ohmyzsh.json wurde nach ../data/projects/ohmyzsh/ verschoben
# Verarbeite: scikit-learn
# ✓ scikit-learn.json wurde nach ../data/projects/scikit-learn/ verschoben
# Verarbeite: deskreen
# ✓ deskreen.json wurde nach ../data/projects/deskreen/ verschoben
# Verarbeite: SwitchHosts
# ✓ SwitchHosts.json wurde nach ../data/projects/SwitchHosts/ verschoben
# Verarbeite: daisyui
# ✓ daisyui.json wurde nach ../data/projects/daisyui/ verschoben
# Verarbeite: prisma
# ✓ prisma.json wurde nach ../data/projects/prisma/ verschoben
# Verarbeite: streamlit
# ✓ streamlit.json wurde nach ../data/projects/streamlit/ verschoben
# Verarbeite: guava
# ✓ guava.json wurde nach ../data/projects/guava/ verschoben
# Verarbeite: barry-ran_QtScrcpy
# ✓ barry-ran_QtScrcpy.json wurde nach ../data/projects/barry-ran_QtScrcpy/ verschoben
# Verarbeite: radare2
# ✓ radare2.json wurde nach ../data/projects/radare2/ verschoben
# Verarbeite: magic-wormhole
# ✓ magic-wormhole.json wurde nach ../data/projects/magic-wormhole/ verschoben
# Verarbeite: kuboard-press
# ✓ kuboard-press.json wurde nach ../data/projects/kuboard-press/ verschoben
# Verarbeite: traefik
# ✓ traefik.json wurde nach ../data/projects/traefik/ verschoben
# Verarbeite: jadx
# ✓ jadx.json wurde nach ../data/projects/jadx/ verschoben
# Verarbeite: ansible_ansible
# ✓ ansible_ansible.json wurde nach ../data/projects/ansible_ansible/ verschoben
# Verarbeite: koa
# ✓ koa.json wurde nach ../data/projects/koa/ verschoben
# Verarbeite: mlc-llm
# ✓ mlc-llm.json wurde nach ../data/projects/mlc-llm/ verschoben
# Verarbeite: cosmopolitan
# ✓ cosmopolitan.json wurde nach ../data/projects/cosmopolitan/ verschoben
# Verarbeite: atuinsh_atuin
# ✓ atuinsh_atuin.json wurde nach ../data/projects/atuinsh_atuin/ verschoben
# Verarbeite: remix
# ✓ remix.json wurde nach ../data/projects/remix/ verschoben
# Verarbeite: filebrowser
# ✓ filebrowser.json wurde nach ../data/projects/filebrowser/ verschoben
# Verarbeite: mitmproxy
# ✓ mitmproxy.json wurde nach ../data/projects/mitmproxy/ verschoben
# Verarbeite: heroicons
# ✓ heroicons.json wurde nach ../data/projects/heroicons/ verschoben
# Verarbeite: YesPlayMusic
# ✓ YesPlayMusic.json wurde nach ../data/projects/YesPlayMusic/ verschoben
# Verarbeite: yoga
# ✓ yoga.json wurde nach ../data/projects/yoga/ verschoben
# Verarbeite: Avalonia
# ✓ Avalonia.json wurde nach ../data/projects/Avalonia/ verschoben
# Verarbeite: yolov5
# ✓ yolov5.json wurde nach ../data/projects/yolov5/ verschoben
# Verarbeite: generative-models
# ✓ generative-models.json wurde nach ../data/projects/generative-models/ verschoben
# Verarbeite: SmsForwarder
# ✓ SmsForwarder.json wurde nach ../data/projects/SmsForwarder/ verschoben
# Verarbeite: netty
# ✓ netty.json wurde nach ../data/projects/netty/ verschoben
# Verarbeite: core
# ✓ core.json wurde nach ../data/projects/core/ verschoben
# Verarbeite: draggable
# ✓ draggable.json wurde nach ../data/projects/draggable/ verschoben
# Verarbeite: vscodium
# ✓ vscodium.json wurde nach ../data/projects/vscodium/ verschoben
# Verarbeite: IOPaint
# ✓ IOPaint.json wurde nach ../data/projects/IOPaint/ verschoben
# Verarbeite: yew
# ✓ yew.json wurde nach ../data/projects/yew/ verschoben
# Verarbeite: homebridge
# ✓ homebridge.json wurde nach ../data/projects/homebridge/ verschoben
# Verarbeite: reflex
# ✓ reflex.json wurde nach ../data/projects/reflex/ verschoben
# Verarbeite: opentofu
# ✓ opentofu.json wurde nach ../data/projects/opentofu/ verschoben
# Verarbeite: pure
# ✓ pure.json wurde nach ../data/projects/pure/ verschoben
# Verarbeite: gkd
# ✓ gkd.json wurde nach ../data/projects/gkd/ verschoben
# Verarbeite: Karabiner-Elements
# ✓ Karabiner-Elements.json wurde nach ../data/projects/Karabiner-Elements/ verschoben
# Verarbeite: fairseq
# ✓ fairseq.json wurde nach ../data/projects/fairseq/ verschoben
# Verarbeite: coreutils
# ✓ coreutils.json wurde nach ../data/projects/coreutils/ verschoben
# Verarbeite: surrealdb
# ✓ surrealdb.json wurde nach ../data/projects/surrealdb/ verschoben
# Verarbeite: koreader
# ✓ koreader.json wurde nach ../data/projects/koreader/ verschoben
# Verarbeite: taipy
# ✓ taipy.json wurde nach ../data/projects/taipy/ verschoben
# Verarbeite: ws
# ✓ ws.json wurde nach ../data/projects/ws/ verschoben
# Verarbeite: DoKit
# ✓ DoKit.json wurde nach ../data/projects/DoKit/ verschoben
# Verarbeite: nuclei
# ✓ nuclei.json wurde nach ../data/projects/nuclei/ verschoben
# Verarbeite: python-telegram-bot
# ✓ python-telegram-bot.json wurde nach ../data/projects/python-telegram-bot/ verschoben
# Verarbeite: kong
# ✓ kong.json wurde nach ../data/projects/kong/ verschoben
# Verarbeite: fullPage.js
# ✓ fullPage.js.json wurde nach ../data/projects/fullPage.js/ verschoben
# Verarbeite: monaco-editor
# ✓ monaco-editor.json wurde nach ../data/projects/monaco-editor/ verschoben
# Verarbeite: wechat-app-mall
# ✓ wechat-app-mall.json wurde nach ../data/projects/wechat-app-mall/ verschoben
# Verarbeite: wezterm
# ✓ wezterm.json wurde nach ../data/projects/wezterm/ verschoben
# Verarbeite: timescaledb
# ✓ timescaledb.json wurde nach ../data/projects/timescaledb/ verschoben
# Verarbeite: glances
# ✓ glances.json wurde nach ../data/projects/glances/ verschoben
# Verarbeite: LunarVim
# ✓ LunarVim.json wurde nach ../data/projects/LunarVim/ verschoben
# Verarbeite: KaTeX
# ✓ KaTeX.json wurde nach ../data/projects/KaTeX/ verschoben
# Verarbeite: eruda
# ✓ eruda.json wurde nach ../data/projects/eruda/ verschoben
# Verarbeite: d2
# ✓ d2.json wurde nach ../data/projects/d2/ verschoben
# Verarbeite: bazel
# ✓ bazel.json wurde nach ../data/projects/bazel/ verschoben
# Verarbeite: go-micro
# ✓ go-micro.json wurde nach ../data/projects/go-micro/ verschoben
# Verarbeite: lucide
# ✓ lucide.json wurde nach ../data/projects/lucide/ verschoben
# Verarbeite: test_project
# ✓ test_project.json wurde nach ../data/projects/test_project/ verschoben
# Verarbeite: hello-algo
# ✓ hello-algo.json wurde nach ../data/projects/hello-algo/ verschoben
# Verarbeite: react-three-fiber
# ✓ react-three-fiber.json wurde nach ../data/projects/react-three-fiber/ verschoben
# Verarbeite: winutil
# ✓ winutil.json wurde nach ../data/projects/winutil/ verschoben
# Verarbeite: ip2region
# ✓ ip2region.json wurde nach ../data/projects/ip2region/ verschoben
# Verarbeite: jumpserver
# ✓ jumpserver.json wurde nach ../data/projects/jumpserver/ verschoben
# Verarbeite: graphql-js
# ✓ graphql-js.json wurde nach ../data/projects/graphql-js/ verschoben
# Verarbeite: cadvisor
# ✓ cadvisor.json wurde nach ../data/projects/cadvisor/ verschoben
# Verarbeite: etherpad-lite
# ✓ etherpad-lite.json wurde nach ../data/projects/etherpad-lite/ verschoben
# Verarbeite: diff-so-fancy
# ✓ diff-so-fancy.json wurde nach ../data/projects/diff-so-fancy/ verschoben
# Verarbeite: sanic
# ✓ sanic.json wurde nach ../data/projects/sanic/ verschoben
# Verarbeite: slim
# ✓ slim.json wurde nach ../data/projects/slim/ verschoben
# Verarbeite: guzzle
# ✓ guzzle.json wurde nach ../data/projects/guzzle/ verschoben
# Verarbeite: dashy
# ✓ dashy.json wurde nach ../data/projects/dashy/ verschoben
# Verarbeite: pingora
# ✓ pingora.json wurde nach ../data/projects/pingora/ verschoben
# Verarbeite: django-rest-framework
# ✓ django-rest-framework.json wurde nach ../data/projects/django-rest-framework/ verschoben
# Verarbeite: fiber
# ✓ fiber.json wurde nach ../data/projects/fiber/ verschoben
# Verarbeite: gin
# ✓ gin.json wurde nach ../data/projects/gin/ verschoben
# Verarbeite: xxl-job
# ✓ xxl-job.json wurde nach ../data/projects/xxl-job/ verschoben
# Verarbeite: dragonfly
# ✓ dragonfly.json wurde nach ../data/projects/dragonfly/ verschoben
# Verarbeite: automa
# ✓ automa.json wurde nach ../data/projects/automa/ verschoben
# Verarbeite: unsloth
# ✓ unsloth.json wurde nach ../data/projects/unsloth/ verschoben
# Verarbeite: node-red
# ✓ node-red.json wurde nach ../data/projects/node-red/ verschoben
# Verarbeite: svelte
# ✓ svelte.json wurde nach ../data/projects/svelte/ verschoben
# Verarbeite: ice
# ✓ ice.json wurde nach ../data/projects/ice/ verschoben
# Verarbeite: mlflow_mlflow
# ✓ mlflow_mlflow.json wurde nach ../data/projects/mlflow_mlflow/ verschoben
# Verarbeite: serve
# ✓ serve.json wurde nach ../data/projects/serve/ verschoben
# Verarbeite: kivy
# ✓ kivy.json wurde nach ../data/projects/kivy/ verschoben
# Verarbeite: heroui-inc_heroui
# ✓ heroui-inc_heroui.json wurde nach ../data/projects/heroui-inc_heroui/ verschoben
# Verarbeite: flatbuffers
# ✓ flatbuffers.json wurde nach ../data/projects/flatbuffers/ verschoben
# Verarbeite: devise
# ✓ devise.json wurde nach ../data/projects/devise/ verschoben
# Verarbeite: valkey
# ✓ valkey.json wurde nach ../data/projects/valkey/ verschoben
# Verarbeite: tailscale
# ✓ tailscale.json wurde nach ../data/projects/tailscale/ verschoben
# Verarbeite: vllm
# ✓ vllm.json wurde nach ../data/projects/vllm/ verschoben
# Verarbeite: jan
# ✓ jan.json wurde nach ../data/projects/jan/ verschoben
# Verarbeite: rancher
# ✓ rancher.json wurde nach ../data/projects/rancher/ verschoben
# Verarbeite: neovim
# ✓ neovim.json wurde nach ../data/projects/neovim/ verschoben
# Verarbeite: openai-python
# ✓ openai-python.json wurde nach ../data/projects/openai-python/ verschoben
# Verarbeite: toml
# ✓ toml.json wurde nach ../data/projects/toml/ verschoben
# Verarbeite: crawl4ai
# ✓ crawl4ai.json wurde nach ../data/projects/crawl4ai/ verschoben
# Verarbeite: hutool
# ✓ hutool.json wurde nach ../data/projects/hutool/ verschoben
# Verarbeite: FastChat
# ✓ FastChat.json wurde nach ../data/projects/FastChat/ verschoben
# Verarbeite: livewire
# ✓ livewire.json wurde nach ../data/projects/livewire/ verschoben
# Verarbeite: xyflow
# ✓ xyflow.json wurde nach ../data/projects/xyflow/ verschoben
# Verarbeite: glance
# ✓ glance.json wurde nach ../data/projects/glance/ verschoben
# Verarbeite: julia
# ✓ julia.json wurde nach ../data/projects/julia/ verschoben
# Verarbeite: video.js
# ✓ video.js.json wurde nach ../data/projects/video.js/ verschoben
# Verarbeite: SDWebImage
# ✓ SDWebImage.json wurde nach ../data/projects/SDWebImage/ verschoben
# Verarbeite: ladybird
# ✓ ladybird.json wurde nach ../data/projects/ladybird/ verschoben
# Verarbeite: openzeppelin-contracts
# ✓ openzeppelin-contracts.json wurde nach ../data/projects/openzeppelin-contracts/ verschoben
# Verarbeite: ant-design
# ✓ ant-design.json wurde nach ../data/projects/ant-design/ verschoben
# Verarbeite: prometheus
# ✓ prometheus.json wurde nach ../data/projects/prometheus/ verschoben
# Verarbeite: lux
# ✓ lux.json wurde nach ../data/projects/lux/ verschoben
# Verarbeite: trix
# ✓ trix.json wurde nach ../data/projects/trix/ verschoben
# Verarbeite: grpc-gateway
# ✓ grpc-gateway.json wurde nach ../data/projects/grpc-gateway/ verschoben
# Verarbeite: matplotlib
# ✓ matplotlib.json wurde nach ../data/projects/matplotlib/ verschoben
# Verarbeite: insightface
# ✓ insightface.json wurde nach ../data/projects/insightface/ verschoben
# Verarbeite: immutable-js
# ✓ immutable-js.json wurde nach ../data/projects/immutable-js/ verschoben
# Verarbeite: deepface
# ✓ deepface.json wurde nach ../data/projects/deepface/ verschoben
# Verarbeite: x64dbg
# ✓ x64dbg.json wurde nach ../data/projects/x64dbg/ verschoben
# Verarbeite: redash
# ✓ redash.json wurde nach ../data/projects/redash/ verschoben
# Verarbeite: open-r1
# ✓ open-r1.json wurde nach ../data/projects/open-r1/ verschoben
# Verarbeite: ripgrep
# ✓ ripgrep.json wurde nach ../data/projects/ripgrep/ verschoben
# Verarbeite: dolt
# ✓ dolt.json wurde nach ../data/projects/dolt/ verschoben
# Verarbeite: youtube-music
# ✓ youtube-music.json wurde nach ../data/projects/youtube-music/ verschoben
# Verarbeite: hosts
# ✓ hosts.json wurde nach ../data/projects/hosts/ verschoben
# Verarbeite: Proton
# ✓ Proton.json wurde nach ../data/projects/Proton/ verschoben
# Verarbeite: localsend
# ✓ localsend.json wurde nach ../data/projects/localsend/ verschoben
# Verarbeite: arthas
# ✓ arthas.json wurde nach ../data/projects/arthas/ verschoben
# Verarbeite: gitleaks
# ✓ gitleaks.json wurde nach ../data/projects/gitleaks/ verschoben
# Verarbeite: OpenManus
# ✓ OpenManus.json wurde nach ../data/projects/OpenManus/ verschoben
# Verarbeite: redoc
# ✓ redoc.json wurde nach ../data/projects/redoc/ verschoben
# Verarbeite: fastapi
# ✓ fastapi.json wurde nach ../data/projects/fastapi/ verschoben
# Verarbeite: containerd
# ✓ containerd.json wurde nach ../data/projects/containerd/ verschoben
# Verarbeite: saleor
# ✓ saleor.json wurde nach ../data/projects/saleor/ verschoben
# Verarbeite: ui
# ✓ ui.json wurde nach ../data/projects/ui/ verschoben
# Verarbeite: emscripten
# ✓ emscripten.json wurde nach ../data/projects/emscripten/ verschoben
# Verarbeite: viper
# ✓ viper.json wurde nach ../data/projects/viper/ verschoben
# Verarbeite: appium
# ✓ appium.json wurde nach ../data/projects/appium/ verschoben
# Verarbeite: SteamTools
# ✓ SteamTools.json wurde nach ../data/projects/SteamTools/ verschoben
# Verarbeite: driver.js
# ✓ driver.js.json wurde nach ../data/projects/driver.js/ verschoben
# Verarbeite: vagrant
# ✓ vagrant.json wurde nach ../data/projects/vagrant/ verschoben
# Verarbeite: typesense
# ✓ typesense.json wurde nach ../data/projects/typesense/ verschoben
# Verarbeite: gleam
# ✓ gleam.json wurde nach ../data/projects/gleam/ verschoben
# Verarbeite: hey
# ✓ hey.json wurde nach ../data/projects/hey/ verschoben
# Verarbeite: ChromeAppHeroes
# ✓ ChromeAppHeroes.json wurde nach ../data/projects/ChromeAppHeroes/ verschoben
# Verarbeite: framework
# ✓ framework.json wurde nach ../data/projects/framework/ verschoben
# Verarbeite: nowinandroid
# ✓ nowinandroid.json wurde nach ../data/projects/nowinandroid/ verschoben
# Verarbeite: mem0
# ✓ mem0.json wurde nach ../data/projects/mem0/ verschoben
# Verarbeite: SwiftLint
# ✓ SwiftLint.json wurde nach ../data/projects/SwiftLint/ verschoben
# Verarbeite: seaweedfs
# ✓ seaweedfs.json wurde nach ../data/projects/seaweedfs/ verschoben
# Verarbeite: ComfyUI
# ✓ ComfyUI.json wurde nach ../data/projects/ComfyUI/ verschoben
# Verarbeite: Seal
# ✓ Seal.json wurde nach ../data/projects/Seal/ verschoben
# Verarbeite: curl
# ✓ curl.json wurde nach ../data/projects/curl/ verschoben
# Verarbeite: esbuild
# ✓ esbuild.json wurde nach ../data/projects/esbuild/ verschoben
# Verarbeite: black
# ✓ black.json wurde nach ../data/projects/black/ verschoben
# Verarbeite: egui
# ✓ egui.json wurde nach ../data/projects/egui/ verschoben
# Verarbeite: Wox
# ✓ Wox.json wurde nach ../data/projects/Wox/ verschoben
# Verarbeite: monica
# ✓ monica.json wurde nach ../data/projects/monica/ verschoben
# Verarbeite: flutter
# ✓ flutter.json wurde nach ../data/projects/flutter/ verschoben
# Verarbeite: etcher
# ✓ etcher.json wurde nach ../data/projects/etcher/ verschoben
# Verarbeite: flask
# ✓ flask.json wurde nach ../data/projects/flask/ verschoben
# Verarbeite: uv
# ✓ uv.json wurde nach ../data/projects/uv/ verschoben
# Verarbeite: nvm
# ✓ nvm.json wurde nach ../data/projects/nvm/ verschoben
# Verarbeite: oven-sh_bun
# ✓ oven-sh_bun.json wurde nach ../data/projects/oven-sh_bun/ verschoben
# Verarbeite: php-src
# ✓ php-src.json wurde nach ../data/projects/php-src/ verschoben
# Verarbeite: pathway
# ✓ pathway.json wurde nach ../data/projects/pathway/ verschoben
# Verarbeite: tmux
# ✓ tmux.json wurde nach ../data/projects/tmux/ verschoben
# Verarbeite: XX-Net
# ✓ XX-Net.json wurde nach ../data/projects/XX-Net/ verschoben
# Verarbeite: recommenders
# ✓ recommenders.json wurde nach ../data/projects/recommenders/ verschoben
# Verarbeite: slidev
# ✓ slidev.json wurde nach ../data/projects/slidev/ verschoben
# Verarbeite: sing-box
# ✓ sing-box.json wurde nach ../data/projects/sing-box/ verschoben
# Verarbeite: HikariCP
# ✓ HikariCP.json wurde nach ../data/projects/HikariCP/ verschoben
# Verarbeite: elixir
# ✓ elixir.json wurde nach ../data/projects/elixir/ verschoben
# Verarbeite: Folo
# ✓ Folo.json wurde nach ../data/projects/Folo/ verschoben
# Verarbeite: onnx
# ✓ onnx.json wurde nach ../data/projects/onnx/ verschoben
# Verarbeite: hiddify-app
# ✓ hiddify-app.json wurde nach ../data/projects/hiddify-app/ verschoben
# Verarbeite: pm2
# ✓ pm2.json wurde nach ../data/projects/pm2/ verschoben
# Verarbeite: unilm
# ✓ unilm.json wurde nach ../data/projects/unilm/ verschoben
# Verarbeite: iTerm2-Color-Schemes
# ✓ iTerm2-Color-Schemes.json wurde nach ../data/projects/iTerm2-Color-Schemes/ verschoben
# Verarbeite: transformers
# ✓ transformers.json wurde nach ../data/projects/transformers/ verschoben
# Verarbeite: rustdesk
# ✓ rustdesk.json wurde nach ../data/projects/rustdesk/ verschoben
# Verarbeite: mindsdb
# ✓ mindsdb.json wurde nach ../data/projects/mindsdb/ verschoben
# Verarbeite: pocketbase
# ✓ pocketbase.json wurde nach ../data/projects/pocketbase/ verschoben
# Verarbeite: WordPress
# ✓ WordPress.json wurde nach ../data/projects/WordPress/ verschoben
# Verarbeite: weui
# ✓ weui.json wurde nach ../data/projects/weui/ verschoben
# Verarbeite: meilisearch
# ✓ meilisearch.json wurde nach ../data/projects/meilisearch/ verschoben
# Verarbeite: laravel-debugbar
# ✓ laravel-debugbar.json wurde nach ../data/projects/laravel-debugbar/ verschoben
# Verarbeite: ddia
# ✓ ddia.json wurde nach ../data/projects/ddia/ verschoben
# Verarbeite: typescript-go
# ✓ typescript-go.json wurde nach ../data/projects/typescript-go/ verschoben
# Verarbeite: solidity
# ✓ solidity.json wurde nach ../data/projects/solidity/ verschoben
# Verarbeite: socket.io
# ✓ socket.io.json wurde nach ../data/projects/socket.io/ verschoben
# Verarbeite: frp
# ✓ frp.json wurde nach ../data/projects/frp/ verschoben
# Verarbeite: ruff
# ✓ ruff.json wurde nach ../data/projects/ruff/ verschoben
# Verarbeite: playwright
# ✓ playwright.json wurde nach ../data/projects/playwright/ verschoben
# Verarbeite: dgtlmoon_changedetection.io
# ✓ dgtlmoon_changedetection.io.json wurde nach ../data/projects/dgtlmoon_changedetection.io/ verschoben
# Verarbeite: unocss
# ✓ unocss.json wurde nach ../data/projects/unocss/ verschoben
# Verarbeite: dokku
# ✓ dokku.json wurde nach ../data/projects/dokku/ verschoben
# Verarbeite: babel
# ✓ babel.json wurde nach ../data/projects/babel/ verschoben
# Verarbeite: svgo
# ✓ svgo.json wurde nach ../data/projects/svgo/ verschoben
# Verarbeite: fmt
# ✓ fmt.json wurde nach ../data/projects/fmt/ verschoben
# Verarbeite: fish-shell
# ✓ fish-shell.json wurde nach ../data/projects/fish-shell/ verschoben
# Verarbeite: imgui
# ✓ imgui.json wurde nach ../data/projects/imgui/ verschoben
# Verarbeite: MagicMirror
# ✓ MagicMirror.json wurde nach ../data/projects/MagicMirror/ verschoben
# Verarbeite: everyone-can-use-english
# ✓ everyone-can-use-english.json wurde nach ../data/projects/everyone-can-use-english/ verschoben
# Verarbeite: dgraph
# ✓ dgraph.json wurde nach ../data/projects/dgraph/ verschoben
# Verarbeite: PowerToys
# ✓ PowerToys.json wurde nach ../data/projects/PowerToys/ verschoben
# Verarbeite: excalidraw
# ✓ excalidraw.json wurde nach ../data/projects/excalidraw/ verschoben
# Verarbeite: compose-samples
# ✓ compose-samples.json wurde nach ../data/projects/compose-samples/ verschoben
# Verarbeite: vim
# ✓ vim.json wurde nach ../data/projects/vim/ verschoben
# Verarbeite: biome
# ✓ biome.json wurde nach ../data/projects/biome/ verschoben
# Verarbeite: egg
# ✓ egg.json wurde nach ../data/projects/egg/ verschoben
# Verarbeite: brew
# ✓ brew.json wurde nach ../data/projects/brew/ verschoben
# Verarbeite: Chart.js
# ✓ Chart.js.json wurde nach ../data/projects/Chart.js/ verschoben
# Verarbeite: halo
# ✓ halo.json wurde nach ../data/projects/halo/ verschoben
# Verarbeite: statsd
# ✓ statsd.json wurde nach ../data/projects/statsd/ verschoben
# Verarbeite: swagger-ui
# ✓ swagger-ui.json wurde nach ../data/projects/swagger-ui/ verschoben
# Verarbeite: gorm
# ✓ gorm.json wurde nach ../data/projects/gorm/ verschoben
# Verarbeite: react-redux
# ✓ react-redux.json wurde nach ../data/projects/react-redux/ verschoben
# Verarbeite: shadowsocks-android
# ✓ shadowsocks-android.json wurde nach ../data/projects/shadowsocks-android/ verschoben
# Verarbeite: HanLP
# ✓ HanLP.json wurde nach ../data/projects/HanLP/ verschoben
# Verarbeite: SingleFile
# ✓ SingleFile.json wurde nach ../data/projects/SingleFile/ verschoben
# Verarbeite: ionicons
# ✓ ionicons.json wurde nach ../data/projects/ionicons/ verschoben
# Verarbeite: reveal.js
# ✓ reveal.js.json wurde nach ../data/projects/reveal.js/ verschoben
# Verarbeite: uptime-kuma
# ✓ uptime-kuma.json wurde nach ../data/projects/uptime-kuma/ verschoben
# Verarbeite: tinygrad
# ✓ tinygrad.json wurde nach ../data/projects/tinygrad/ verschoben
# Verarbeite: czkawka
# ✓ czkawka.json wurde nach ../data/projects/czkawka/ verschoben
# Verarbeite: mlx
# ✓ mlx.json wurde nach ../data/projects/mlx/ verschoben
# Verarbeite: LocalAI
# ✓ LocalAI.json wurde nach ../data/projects/LocalAI/ verschoben
# Verarbeite: slate
# ✓ slate.json wurde nach ../data/projects/slate/ verschoben
# Verarbeite: spleeter
# ✓ spleeter.json wurde nach ../data/projects/spleeter/ verschoben
# Verarbeite: chroma
# ✓ chroma.json wurde nach ../data/projects/chroma/ verschoben
# Verarbeite: node
# ✓ node.json wurde nach ../data/projects/node/ verschoben
# Verarbeite: okhttp
# ✓ okhttp.json wurde nach ../data/projects/okhttp/ verschoben
# Verarbeite: pytorch-lightning
# ✓ pytorch-lightning.json wurde nach ../data/projects/pytorch-lightning/ verschoben
# Verarbeite: OCRmyPDF
# ✓ OCRmyPDF.json wurde nach ../data/projects/OCRmyPDF/ verschoben
# Verarbeite: mongoose
# ✓ mongoose.json wurde nach ../data/projects/mongoose/ verschoben
# Verarbeite: lerna
# ✓ lerna.json wurde nach ../data/projects/lerna/ verschoben
# Verarbeite: faker
# ✓ faker.json wurde nach ../data/projects/faker/ verschoben
# Verarbeite: raylib
# ✓ raylib.json wurde nach ../data/projects/raylib/ verschoben
# Verarbeite: wasmer
# ✓ wasmer.json wurde nach ../data/projects/wasmer/ verschoben
# Verarbeite: TDengine
# ✓ TDengine.json wurde nach ../data/projects/TDengine/ verschoben
# Verarbeite: PHPMailer
# ✓ PHPMailer.json wurde nach ../data/projects/PHPMailer/ verschoben
# Verarbeite: clash-verge-rev
# ✓ clash-verge-rev.json wurde nach ../data/projects/clash-verge-rev/ verschoben
# Verarbeite: jax
# ✓ jax.json wurde nach ../data/projects/jax/ verschoben
# Verarbeite: gpt4all
# ✓ gpt4all.json wurde nach ../data/projects/gpt4all/ verschoben
# Verarbeite: mpv
# ✓ mpv.json wurde nach ../data/projects/mpv/ verschoben
# Verarbeite: daytona
# ✓ daytona.json wurde nach ../data/projects/daytona/ verschoben
# Verarbeite: crewAI
# ✓ crewAI.json wurde nach ../data/projects/crewAI/ verschoben
# Verarbeite: crystal
# ✓ crystal.json wurde nach ../data/projects/crystal/ verschoben
# Verarbeite: fabric
# ✓ fabric.json wurde nach ../data/projects/fabric/ verschoben
# Verarbeite: create-t3-app
# ✓ create-t3-app.json wurde nach ../data/projects/create-t3-app/ verschoben
# Verarbeite: pi-hole
# ✓ pi-hole.json wurde nach ../data/projects/pi-hole/ verschoben
# Verarbeite: components
# ✓ components.json wurde nach ../data/projects/components/ verschoben
# Verarbeite: testify
# ✓ testify.json wurde nach ../data/projects/testify/ verschoben
# Verarbeite: Qwen3
# ✓ Qwen3.json wurde nach ../data/projects/Qwen3/ verschoben
# Verarbeite: react-spring
# ✓ react-spring.json wurde nach ../data/projects/react-spring/ verschoben
# Verarbeite: SmartTube
# ✓ SmartTube.json wurde nach ../data/projects/SmartTube/ verschoben
# Verarbeite: luigi
# ✓ luigi.json wurde nach ../data/projects/luigi/ verschoben
# Verarbeite: filament
# ✓ filament.json wurde nach ../data/projects/filament/ verschoben
# Verarbeite: dub
# ✓ dub.json wurde nach ../data/projects/dub/ verschoben
# Verarbeite: servers
# ✓ servers.json wurde nach ../data/projects/servers/ verschoben
# Verarbeite: stb
# ✓ stb.json wurde nach ../data/projects/stb/ verschoben
# Verarbeite: htmx
# ✓ htmx.json wurde nach ../data/projects/htmx/ verschoben
# Verarbeite: kotaemon
# ✓ kotaemon.json wurde nach ../data/projects/kotaemon/ verschoben
# Verarbeite: carbon-lang
# ✓ carbon-lang.json wurde nach ../data/projects/carbon-lang/ verschoben
# Verarbeite: SwiftyJSON
# ✓ SwiftyJSON.json wurde nach ../data/projects/SwiftyJSON/ verschoben
# Verarbeite: react-hook-form
# ✓ react-hook-form.json wurde nach ../data/projects/react-hook-form/ verschoben
# Verarbeite: CymChad_BaseRecyclerViewAdapterHelper
# ✓ CymChad_BaseRecyclerViewAdapterHelper.json wurde nach ../data/projects/CymChad_BaseRecyclerViewAdapterHelper/ verschoben
# Verarbeite: vueuse
# ✓ vueuse.json wurde nach ../data/projects/vueuse/ verschoben
# Verarbeite: dspy
# ✓ dspy.json wurde nach ../data/projects/dspy/ verschoben
# Verarbeite: prettier
# ✓ prettier.json wurde nach ../data/projects/prettier/ verschoben
# Verarbeite: kit
# ✓ kit.json wurde nach ../data/projects/kit/ verschoben
# Verarbeite: gpt4free
# ✓ gpt4free.json wurde nach ../data/projects/gpt4free/ verschoben
# Verarbeite: 1Panel
# ✓ 1Panel.json wurde nach ../data/projects/1Panel/ verschoben
# Verarbeite: validator.js
# ✓ validator.js.json wurde nach ../data/projects/validator.js/ verschoben
# Verarbeite: linux-command
# ✓ linux-command.json wurde nach ../data/projects/linux-command/ verschoben
# Verarbeite: slick
# ✓ slick.json wurde nach ../data/projects/slick/ verschoben
# Verarbeite: MinerU
# ✓ MinerU.json wurde nach ../data/projects/MinerU/ verschoben
# Verarbeite: drawdb
# ✓ drawdb.json wurde nach ../data/projects/drawdb/ verschoben
# Verarbeite: maybe
# ✓ maybe.json wurde nach ../data/projects/maybe/ verschoben
# Verarbeite: DeepSeek-V3
# ✓ DeepSeek-V3.json wurde nach ../data/projects/DeepSeek-V3/ verschoben
# Verarbeite: ILSpy
# ✓ ILSpy.json wurde nach ../data/projects/ILSpy/ verschoben
# Verarbeite: ollama
# ✓ ollama.json wurde nach ../data/projects/ollama/ verschoben
# Verarbeite: n
# ✓ n.json wurde nach ../data/projects/n/ verschoben
# Verarbeite: highlight.js
# ✓ highlight.js.json wurde nach ../data/projects/highlight.js/ verschoben
# Verarbeite: vulhub
# ✓ vulhub.json wurde nach ../data/projects/vulhub/ verschoben
# Verarbeite: NationalSecurityAgency_ghidra
# ✓ NationalSecurityAgency_ghidra.json wurde nach ../data/projects/NationalSecurityAgency_ghidra/ verschoben
# Verarbeite: GSYVideoPlayer
# ✓ GSYVideoPlayer.json wurde nach ../data/projects/GSYVideoPlayer/ verschoben
# Verarbeite: rufus
# ✓ rufus.json wurde nach ../data/projects/rufus/ verschoben
# Verarbeite: v86
# ✓ v86.json wurde nach ../data/projects/v86/ verschoben
# Verarbeite: postcss
# ✓ postcss.json wurde nach ../data/projects/postcss/ verschoben
# Verarbeite: aider
# ✓ aider.json wurde nach ../data/projects/aider/ verschoben
# Verarbeite: joi
# ✓ joi.json wurde nach ../data/projects/joi/ verschoben
# Verarbeite: smolagents
# ✓ smolagents.json wurde nach ../data/projects/smolagents/ verschoben
# Verarbeite: tailwindcss
# ✓ tailwindcss.json wurde nach ../data/projects/tailwindcss/ verschoben
# Verarbeite: graphrag
# ✓ graphrag.json wurde nach ../data/projects/graphrag/ verschoben
# Verarbeite: OSX-KVM
# ✓ OSX-KVM.json wurde nach ../data/projects/OSX-KVM/ verschoben
# Verarbeite: hexo
# ✓ hexo.json wurde nach ../data/projects/hexo/ verschoben
# Verarbeite: marker
# ✓ marker.json wurde nach ../data/projects/marker/ verschoben
# Verarbeite: uppy
# ✓ uppy.json wurde nach ../data/projects/uppy/ verschoben
# Verarbeite: micropython
# ✓ micropython.json wurde nach ../data/projects/micropython/ verschoben
# Verarbeite: rrweb
# ✓ rrweb.json wurde nach ../data/projects/rrweb/ verschoben
# Verarbeite: Leaflet
# ✓ Leaflet.json wurde nach ../data/projects/Leaflet/ verschoben
# Verarbeite: wg-easy
# ✓ wg-easy.json wurde nach ../data/projects/wg-easy/ verschoben
# Verarbeite: vimium
# ✓ vimium.json wurde nach ../data/projects/vimium/ verschoben
# Verarbeite: ant-design-pro
# ✓ ant-design-pro.json wurde nach ../data/projects/ant-design-pro/ verschoben
# Verarbeite: act
# ✓ act.json wurde nach ../data/projects/act/ verschoben
# Verarbeite: llm.c
# ✓ llm.c.json wurde nach ../data/projects/llm.c/ verschoben
# Verarbeite: srs
# ✓ srs.json wurde nach ../data/projects/srs/ verschoben
# Verarbeite: nlohmann_json
# ✓ nlohmann_json.json wurde nach ../data/projects/nlohmann_json/ verschoben
# Verarbeite: mall
# ✓ mall.json wurde nach ../data/projects/mall/ verschoben
# Verarbeite: OmniParser
# ✓ OmniParser.json wurde nach ../data/projects/OmniParser/ verschoben
# Verarbeite: Real-Time-Voice-Cloning
# ✓ Real-Time-Voice-Cloning.json wurde nach ../data/projects/Real-Time-Voice-Cloning/ verschoben
# Verarbeite: terminal
# ✓ terminal.json wurde nach ../data/projects/terminal/ verschoben
# Verarbeite: freqtrade
# ✓ freqtrade.json wurde nach ../data/projects/freqtrade/ verschoben
# Verarbeite: numpy
# ✓ numpy.json wurde nach ../data/projects/numpy/ verschoben
# Verarbeite: starship
# ✓ starship.json wurde nach ../data/projects/starship/ verschoben
# Verarbeite: whisper
# ✓ whisper.json wurde nach ../data/projects/whisper/ verschoben
# Verarbeite: MediaCrawler
# ✓ MediaCrawler.json wurde nach ../data/projects/MediaCrawler/ verschoben
# Verarbeite: hoppscotch
# ✓ hoppscotch.json wurde nach ../data/projects/hoppscotch/ verschoben
# Verarbeite: ml-agents
# ✓ ml-agents.json wurde nach ../data/projects/ml-agents/ verschoben
# Verarbeite: servo_servo
# ✓ servo_servo.json wurde nach ../data/projects/servo_servo/ verschoben
# Verarbeite: python-fire
# ✓ python-fire.json wurde nach ../data/projects/python-fire/ verschoben
# Verarbeite: OI-wiki
# ✓ OI-wiki.json wurde nach ../data/projects/OI-wiki/ verschoben
# Verarbeite: jest
# ✓ jest.json wurde nach ../data/projects/jest/ verschoben
# Verarbeite: tornado
# ✓ tornado.json wurde nach ../data/projects/tornado/ verschoben
# Verarbeite: FiraCode
# ✓ FiraCode.json wurde nach ../data/projects/FiraCode/ verschoben
# Verarbeite: bokeh
# ✓ bokeh.json wurde nach ../data/projects/bokeh/ verschoben
# Verarbeite: docs
# ✓ docs.json wurde nach ../data/projects/docs/ verschoben
# Verarbeite: UTM
# ✓ UTM.json wurde nach ../data/projects/UTM/ verschoben
# Verarbeite: bulletproof-react
# ✓ bulletproof-react.json wurde nach ../data/projects/bulletproof-react/ verschoben
# Verarbeite: bitcoin
# ✓ bitcoin.json wurde nach ../data/projects/bitcoin/ verschoben
# Verarbeite: FastGPT
# ✓ FastGPT.json wurde nach ../data/projects/FastGPT/ verschoben
# Verarbeite: kafka
# ✓ kafka.json wurde nach ../data/projects/kafka/ verschoben
# Verarbeite: jsdom
# ✓ jsdom.json wurde nach ../data/projects/jsdom/ verschoben
# Verarbeite: vnpy
# ✓ vnpy.json wurde nach ../data/projects/vnpy/ verschoben
# Verarbeite: dayjs
# ✓ dayjs.json wurde nach ../data/projects/dayjs/ verschoben
# Verarbeite: composer
# ✓ composer.json wurde nach ../data/projects/composer/ verschoben
# Verarbeite: core-js
# ✓ core-js.json wurde nach ../data/projects/core-js/ verschoben
# Verarbeite: pulumi
# ✓ pulumi.json wurde nach ../data/projects/pulumi/ verschoben
# Verarbeite: excelize
# ✓ excelize.json wurde nach ../data/projects/excelize/ verschoben
# Verarbeite: NvChad
# ✓ NvChad.json wurde nach ../data/projects/NvChad/ verschoben
# Verarbeite: sqlmap
# ✓ sqlmap.json wurde nach ../data/projects/sqlmap/ verschoben
# Verarbeite: go-redis
# ✓ go-redis.json wurde nach ../data/projects/go-redis/ verschoben
# Verarbeite: ink
# ✓ ink.json wurde nach ../data/projects/ink/ verschoben
# Verarbeite: flux
# ✓ flux.json wurde nach ../data/projects/flux/ verschoben
# Verarbeite: faiss
# ✓ faiss.json wurde nach ../data/projects/faiss/ verschoben
# Verarbeite: table
# ✓ table.json wurde nach ../data/projects/table/ verschoben
# Verarbeite: ava
# ✓ ava.json wurde nach ../data/projects/ava/ verschoben
# Verarbeite: anki
# ✓ anki.json wurde nach ../data/projects/anki/ verschoben
# Verarbeite: OpenHands
# ✓ OpenHands.json wurde nach ../data/projects/OpenHands/ verschoben
# Verarbeite: hashcat
# ✓ hashcat.json wurde nach ../data/projects/hashcat/ verschoben
# Verarbeite: chatgpt-on-wechat
# ✓ chatgpt-on-wechat.json wurde nach ../data/projects/chatgpt-on-wechat/ verschoben
# Verarbeite: autocomplete
# ✓ autocomplete.json wurde nach ../data/projects/autocomplete/ verschoben
# Verarbeite: markitdown
# ✓ markitdown.json wurde nach ../data/projects/markitdown/ verschoben
# Verarbeite: nw.js
# ✓ nw.js.json wurde nach ../data/projects/nw.js/ verschoben
# Verarbeite: framework7
# ✓ framework7.json wurde nach ../data/projects/framework7/ verschoben
# Verarbeite: uni-app
# ✓ uni-app.json wurde nach ../data/projects/uni-app/ verschoben
# Verarbeite: Apollo-11
# ✓ Apollo-11.json wurde nach ../data/projects/Apollo-11/ verschoben
# Verarbeite: zig
# ✓ zig.json wurde nach ../data/projects/zig/ verschoben
# Verarbeite: shellcheck
# ✓ shellcheck.json wurde nach ../data/projects/shellcheck/ verschoben
# Verarbeite: hugo
# ✓ hugo.json wurde nach ../data/projects/hugo/ verschoben
# Verarbeite: LazyVim
# ✓ LazyVim.json wurde nach ../data/projects/LazyVim/ verschoben
# Verarbeite: keras
# ✓ keras.json wurde nach ../data/projects/keras/ verschoben
# Verarbeite: axum
# ✓ axum.json wurde nach ../data/projects/axum/ verschoben
# Verarbeite: ungoogled-chromium
# ✓ ungoogled-chromium.json wurde nach ../data/projects/ungoogled-chromium/ verschoben
# Verarbeite: colima
# ✓ colima.json wurde nach ../data/projects/colima/ verschoben
# Verarbeite: nushell
# ✓ nushell.json wurde nach ../data/projects/nushell/ verschoben
# Verarbeite: twenty
# ✓ twenty.json wurde nach ../data/projects/twenty/ verschoben
# Verarbeite: spring-cloud-alibaba
# ✓ spring-cloud-alibaba.json wurde nach ../data/projects/spring-cloud-alibaba/ verschoben
# Verarbeite: RxJava
# ✓ RxJava.json wurde nach ../data/projects/RxJava/ verschoben
# Verarbeite: chi
# ✓ chi.json wurde nach ../data/projects/chi/ verschoben
# Verarbeite: pyenv
# ✓ pyenv.json wurde nach ../data/projects/pyenv/ verschoben
# Verarbeite: mimikatz
# ✓ mimikatz.json wurde nach ../data/projects/mimikatz/ verschoben
# Verarbeite: webtorrent
# ✓ webtorrent.json wurde nach ../data/projects/webtorrent/ verschoben
# Verarbeite: upscayl
# ✓ upscayl.json wurde nach ../data/projects/upscayl/ verschoben
# Verarbeite: gpt_academic
# ✓ gpt_academic.json wurde nach ../data/projects/gpt_academic/ verschoben
# Verarbeite: manim
# ✓ manim.json wurde nach ../data/projects/manim/ verschoben
# Verarbeite: RustPython
# ✓ RustPython.json wurde nach ../data/projects/RustPython/ verschoben
# Verarbeite: desktop
# ✓ desktop.json wurde nach ../data/projects/desktop/ verschoben
# Verarbeite: apollo
# ✓ apollo.json wurde nach ../data/projects/apollo/ verschoben
# Verarbeite: gradle
# ✓ gradle.json wurde nach ../data/projects/gradle/ verschoben
# Verarbeite: theia
# ✓ theia.json wurde nach ../data/projects/theia/ verschoben
# Verarbeite: element-plus
# ✓ element-plus.json wurde nach ../data/projects/element-plus/ verschoben
# Verarbeite: ncnn
# ✓ ncnn.json wurde nach ../data/projects/ncnn/ verschoben
# Verarbeite: gin-vue-admin
# ✓ gin-vue-admin.json wurde nach ../data/projects/gin-vue-admin/ verschoben
# Verarbeite: v
# ✓ v.json wurde nach ../data/projects/v/ verschoben
# Verarbeite: Alamofire
# ✓ Alamofire.json wurde nach ../data/projects/Alamofire/ verschoben
# Verarbeite: next-auth
# ✓ next-auth.json wurde nach ../data/projects/next-auth/ verschoben
# Verarbeite: lvgl
# ✓ lvgl.json wurde nach ../data/projects/lvgl/ verschoben
# Verarbeite: huginn
# ✓ huginn.json wurde nach ../data/projects/huginn/ verschoben
# Verarbeite: phoenix
# ✓ phoenix.json wurde nach ../data/projects/phoenix/ verschoben
# Verarbeite: ExplorerPatcher
# ✓ ExplorerPatcher.json wurde nach ../data/projects/ExplorerPatcher/ verschoben
# Verarbeite: trpc
# ✓ trpc.json wurde nach ../data/projects/trpc/ verschoben
# Verarbeite: jaegertracing_jaeger
# ✓ jaegertracing_jaeger.json wurde nach ../data/projects/jaegertracing_jaeger/ verschoben
# Verarbeite: bilibili-API-collect
# ✓ bilibili-API-collect.json wurde nach ../data/projects/bilibili-API-collect/ verschoben
# Verarbeite: MoneyPrinterTurbo
# ✓ MoneyPrinterTurbo.json wurde nach ../data/projects/MoneyPrinterTurbo/ verschoben
# Verarbeite: linera-protocol
# ✓ linera-protocol.json wurde nach ../data/projects/linera-protocol/ verschoben
# Verarbeite: yjs
# ✓ yjs.json wurde nach ../data/projects/yjs/ verschoben
# Verarbeite: react-native-web
# ✓ react-native-web.json wurde nach ../data/projects/react-native-web/ verschoben
# Verarbeite: coc.nvim
# ✓ coc.nvim.json wurde nach ../data/projects/coc.nvim/ verschoben
# Verarbeite: youtube-dl
# ✓ youtube-dl.json wurde nach ../data/projects/youtube-dl/ verschoben
# Verarbeite: fasthttp
# ✓ fasthttp.json wurde nach ../data/projects/fasthttp/ verschoben
# Verarbeite: Ehviewer_CN_SXJ
# ✓ Ehviewer_CN_SXJ.json wurde nach ../data/projects/Ehviewer_CN_SXJ/ verschoben
# Verarbeite: lo
# ✓ lo.json wurde nach ../data/projects/lo/ verschoben
# Verarbeite: zod
# ✓ zod.json wurde nach ../data/projects/zod/ verschoben
# Verarbeite: TrafficMonitor
# ✓ TrafficMonitor.json wurde nach ../data/projects/TrafficMonitor/ verschoben
# Verarbeite: reduxjs_redux
# ✓ reduxjs_redux.json wurde nach ../data/projects/reduxjs_redux/ verschoben
# Verarbeite: mypy
# ✓ mypy.json wurde nach ../data/projects/mypy/ verschoben
# Verarbeite: mdb-ui-kit
# ✓ mdb-ui-kit.json wurde nach ../data/projects/mdb-ui-kit/ verschoben
# Verarbeite: tesseract.js
# ✓ tesseract.js.json wurde nach ../data/projects/tesseract.js/ verschoben
# Verarbeite: badges_shields
# ✓ badges_shields.json wurde nach ../data/projects/badges_shields/ verschoben
# Verarbeite: outline
# ✓ outline.json wurde nach ../data/projects/outline/ verschoben
# Verarbeite: leptos
# ✓ leptos.json wurde nach ../data/projects/leptos/ verschoben
# Verarbeite: gradio
# ✓ gradio.json wurde nach ../data/projects/gradio/ verschoben
# Verarbeite: GyulyVGC_sniffnet
# ✓ GyulyVGC_sniffnet.json wurde nach ../data/projects/GyulyVGC_sniffnet/ verschoben
# Verarbeite: deno
# ✓ deno.json wurde nach ../data/projects/deno/ verschoben
# Verarbeite: LightRAG
# ✓ LightRAG.json wurde nach ../data/projects/LightRAG/ verschoben
# Verarbeite: layui
# ✓ layui.json wurde nach ../data/projects/layui/ verschoben
# Verarbeite: rocksdb
# ✓ rocksdb.json wurde nach ../data/projects/rocksdb/ verschoben
# Verarbeite: tesseract
# ✓ tesseract.json wurde nach ../data/projects/tesseract/ verschoben
# Verarbeite: tldraw_tldraw
# ✓ tldraw_tldraw.json wurde nach ../data/projects/tldraw_tldraw/ verschoben
# Verarbeite: textual
# ✓ textual.json wurde nach ../data/projects/textual/ verschoben
# Verarbeite: serverless
# ✓ serverless.json wurde nach ../data/projects/serverless/ verschoben
# Verarbeite: docker-elk
# ✓ docker-elk.json wurde nach ../data/projects/docker-elk/ verschoben
# Verarbeite: NewPipe
# ✓ NewPipe.json wurde nach ../data/projects/NewPipe/ verschoben
# Verarbeite: express
# ✓ express.json wurde nach ../data/projects/express/ verschoben
# Verarbeite: tauri
# ✓ tauri.json wurde nach ../data/projects/tauri/ verschoben
# Verarbeite: Sunshine
# ✓ Sunshine.json wurde nach ../data/projects/Sunshine/ verschoben
# Verarbeite: GPT-SoVITS
# ✓ GPT-SoVITS.json wurde nach ../data/projects/GPT-SoVITS/ verschoben
# Verarbeite: redisson
# ✓ redisson.json wurde nach ../data/projects/redisson/ verschoben
# Verarbeite: envoy
# ✓ envoy.json wurde nach ../data/projects/envoy/ verschoben
# Verarbeite: v2rayN
# ✓ v2rayN.json wurde nach ../data/projects/v2rayN/ verschoben
# Verarbeite: cobalt
# ✓ cobalt.json wurde nach ../data/projects/cobalt/ verschoben
# Verarbeite: keepassxc
# ✓ keepassxc.json wurde nach ../data/projects/keepassxc/ verschoben
# Verarbeite: agenticSeek
# ✓ agenticSeek.json wurde nach ../data/projects/agenticSeek/ verschoben
# Verarbeite: podman
# ✓ podman.json wurde nach ../data/projects/podman/ verschoben
# Verarbeite: Iosevka
# ✓ Iosevka.json wurde nach ../data/projects/Iosevka/ verschoben
# Verarbeite: logseq
# ✓ logseq.json wurde nach ../data/projects/logseq/ verschoben
# Verarbeite: pytorch_geometric
# ✓ pytorch_geometric.json wurde nach ../data/projects/pytorch_geometric/ verschoben
# Verarbeite: FreeCAD
# ✓ FreeCAD.json wurde nach ../data/projects/FreeCAD/ verschoben
# Verarbeite: vitess
# ✓ vitess.json wurde nach ../data/projects/vitess/ verschoben
# Verarbeite: gulp
# ✓ gulp.json wurde nach ../data/projects/gulp/ verschoben
# Verarbeite: pixijs
# ✓ pixijs.json wurde nach ../data/projects/pixijs/ verschoben
# Verarbeite: ShareX
# ✓ ShareX.json wurde nach ../data/projects/ShareX/ verschoben
# Verarbeite: shardeum
# ✓ shardeum.json wurde nach ../data/projects/shardeum/ verschoben
# Verarbeite: Rectangle
# ✓ Rectangle.json wurde nach ../data/projects/Rectangle/ verschoben
# Verarbeite: monolog
# ✓ monolog.json wurde nach ../data/projects/monolog/ verschoben
# Verarbeite: kotlin
# ✓ kotlin.json wurde nach ../data/projects/kotlin/ verschoben
# Verarbeite: intro.js
# ✓ intro.js.json wurde nach ../data/projects/intro.js/ verschoben
# Verarbeite: iina
# ✓ iina.json wurde nach ../data/projects/iina/ verschoben
# Verarbeite: terraform
# ✓ terraform.json wurde nach ../data/projects/terraform/ verschoben
# ...
# Verarbeite: Apktool
# ✓ Apktool.json wurde nach ../data/projects/Apktool/ verschoben
# Verarbeite: semantic-release
# ✓ semantic-release.json wurde nach ../data/projects/semantic-release/ verschoben
# Verarbeite: sherlock
# ✓ sherlock.json wurde nach ../data/projects/sherlock/ verschoben
# Verarbeite: quivr
# ✓ quivr.json wurde nach ../data/projects/quivr/ verschoben
# Verarbeite: vue-pure-admin
# ✓ vue-pure-admin.json wurde nach ../data/projects/vue-pure-admin/ verschoben
# Verarbeite: OpenVoice
# ✓ OpenVoice.json wurde nach ../data/projects/OpenVoice/ verschoben
# Verarbeite: zstd
# ✓ zstd.json wurde nach ../data/projects/zstd/ verschoben
# Verarbeite: oh-my-posh
# ✓ oh-my-posh.json wurde nach ../data/projects/oh-my-posh/ verschoben
# Verarbeite: github-readme-stats
# ✓ github-readme-stats.json wurde nach ../data/projects/github-readme-stats/ verschoben
# Verarbeite: react-native
# ✓ react-native.json wurde nach ../data/projects/react-native/ verschoben
# Verarbeite: Anuken_Mindustry
# ✓ Anuken_Mindustry.json wurde nach ../data/projects/Anuken_Mindustry/ verschoben
# Verarbeite: codex
# ✓ codex.json wurde nach ../data/projects/codex/ verschoben
# Verarbeite: poetry
# ✓ poetry.json wurde nach ../data/projects/poetry/ verschoben
# Verarbeite: calculator
# ✓ calculator.json wurde nach ../data/projects/calculator/ verschoben
# Verarbeite: firecrawl
# ✓ firecrawl.json wurde nach ../data/projects/firecrawl/ verschoben
# Verarbeite: ruoyi-vue-pro
# ✓ ruoyi-vue-pro.json wurde nach ../data/projects/ruoyi-vue-pro/ verschoben
# Verarbeite: prophet
# ✓ prophet.json wurde nach ../data/projects/prophet/ verschoben
# Verarbeite: caddy
# ✓ caddy.json wurde nach ../data/projects/caddy/ verschoben
# Verarbeite: dioxus
# ✓ dioxus.json wurde nach ../data/projects/dioxus/ verschoben
# Verarbeite: sharp
# ✓ sharp.json wurde nach ../data/projects/sharp/ verschoben
# Verarbeite: openwrt
# ✓ openwrt.json wurde nach ../data/projects/openwrt/ verschoben
# Verarbeite: nginx-proxy
# ✓ nginx-proxy.json wurde nach ../data/projects/nginx-proxy/ verschoben
# Verarbeite: commander.js
# ✓ commander.js.json wurde nach ../data/projects/commander.js/ verschoben
# Verarbeite: onlook
# ✓ onlook.json wurde nach ../data/projects/onlook/ verschoben
# Verarbeite: restic
# ✓ restic.json wurde nach ../data/projects/restic/ verschoben
# Verarbeite: scrapy
# ✓ scrapy.json wurde nach ../data/projects/scrapy/ verschoben
# Verarbeite: portainer
# ✓ portainer.json wurde nach ../data/projects/portainer/ verschoben
# Verarbeite: stanford-oval_storm
# ✓ stanford-oval_storm.json wurde nach ../data/projects/stanford-oval_storm/ verschoben
# Verarbeite: screenshot-to-code
# ✓ screenshot-to-code.json wurde nach ../data/projects/screenshot-to-code/ verschoben
# Verarbeite: mybatis-3
# ✓ mybatis-3.json wurde nach ../data/projects/mybatis-3/ verschoben
# Verarbeite: xstate
# ✓ xstate.json wurde nach ../data/projects/xstate/ verschoben
# Verarbeite: vite
# ✓ vite.json wurde nach ../data/projects/vite/ verschoben
# Verarbeite: pdf.js
# ✓ pdf.js.json wurde nach ../data/projects/pdf.js/ verschoben
# Verarbeite: sqlitebrowser
# ✓ sqlitebrowser.json wurde nach ../data/projects/sqlitebrowser/ verschoben
# Verarbeite: protobuf
# ✓ protobuf.json wurde nach ../data/projects/protobuf/ verschoben
# Verarbeite: motion
# ✓ motion.json wurde nach ../data/projects/motion/ verschoben
# Verarbeite: age
# ✓ age.json wurde nach ../data/projects/age/ verschoben
# Verarbeite: anything-llm
# ✓ anything-llm.json wurde nach ../data/projects/anything-llm/ verschoben
# Verarbeite: bubbletea
# ✓ bubbletea.json wurde nach ../data/projects/bubbletea/ verschoben
# Verarbeite: eladmin
# ✓ eladmin.json wurde nach ../data/projects/eladmin/ verschoben
# Verarbeite: recharts
# ✓ recharts.json wurde nach ../data/projects/recharts/ verschoben
# Verarbeite: continuedev_continue
# ✓ continuedev_continue.json wurde nach ../data/projects/continuedev_continue/ verschoben
# Verarbeite: AdGuardHome
# ✓ AdGuardHome.json wurde nach ../data/projects/AdGuardHome/ verschoben
# Verarbeite: jellyfin
# ✓ jellyfin.json wurde nach ../data/projects/jellyfin/ verschoben
# Verarbeite: ImHex
# ✓ ImHex.json wurde nach ../data/projects/ImHex/ verschoben
# Verarbeite: vant
# ✓ vant.json wurde nach ../data/projects/vant/ verschoben
# Verarbeite: RevokeMsgPatcher
# ✓ RevokeMsgPatcher.json wurde nach ../data/projects/RevokeMsgPatcher/ verschoben
# Verarbeite: doomemacs
# ✓ doomemacs.json wurde nach ../data/projects/doomemacs/ verschoben
# Verarbeite: compiler-explorer_compiler-explorer
# ✓ compiler-explorer_compiler-explorer.json wurde nach ../data/projects/compiler-explorer_compiler-explorer/ verschoben
# Verarbeite: pipenv
# ✓ pipenv.json wurde nach ../data/projects/pipenv/ verschoben
# Verarbeite: mkdocs-material
# ✓ mkdocs-material.json wurde nach ../data/projects/mkdocs-material/ verschoben
# Verarbeite: dev-sidecar
# ✓ dev-sidecar.json wurde nach ../data/projects/dev-sidecar/ verschoben
# Verarbeite: tokio
# ✓ tokio.json wurde nach ../data/projects/tokio/ verschoben
# Verarbeite: lucide-icons_lucide
# ✓ lucide-icons_lucide.json wurde nach ../data/projects/lucide-icons_lucide/ verschoben
# Verarbeite: CodeEdit
# ✓ CodeEdit.json wurde nach ../data/projects/CodeEdit/ verschoben
# Verarbeite: micro
# ✓ micro.json wurde nach ../data/projects/micro/ verschoben
# Verarbeite: spacedrive
# ✓ spacedrive.json wurde nach ../data/projects/spacedrive/ verschoben
# Verarbeite: wails
# ✓ wails.json wurde nach ../data/projects/wails/ verschoben
# Verarbeite: html5-boilerplate
# ✓ html5-boilerplate.json wurde nach ../data/projects/html5-boilerplate/ verschoben
# Verarbeite: tabler-icons
# ✓ tabler-icons.json wurde nach ../data/projects/tabler-icons/ verschoben
# Verarbeite: typeorm
# ✓ typeorm.json wurde nach ../data/projects/typeorm/ verschoben
# Verarbeite: source-code-hunter
# ✓ source-code-hunter.json wurde nach ../data/projects/source-code-hunter/ verschoben
# Verarbeite: code-server
# ✓ code-server.json wurde nach ../data/projects/code-server/ verschoben
# Verarbeite: neon
# ✓ neon.json wurde nach ../data/projects/neon/ verschoben
# Verarbeite: supervision
# ✓ supervision.json wurde nach ../data/projects/supervision/ verschoben
# Verarbeite: harness
# ✓ harness.json wurde nach ../data/projects/harness/ verschoben
# Verarbeite: invoke-ai_InvokeAI
# ✓ invoke-ai_InvokeAI.json wurde nach ../data/projects/invoke-ai_InvokeAI/ verschoben
# Verarbeite: grpc-go
# ✓ grpc-go.json wurde nach ../data/projects/grpc-go/ verschoben
# Verarbeite: devdocs
# ✓ devdocs.json wurde nach ../data/projects/devdocs/ verschoben
# Verarbeite: composio
# ✓ composio.json wurde nach ../data/projects/composio/ verschoben
# Verarbeite: rocketmq
# ✓ rocketmq.json wurde nach ../data/projects/rocketmq/ verschoben
# Verarbeite: spacemacs
# ✓ spacemacs.json wurde nach ../data/projects/spacemacs/ verschoben
# Verarbeite: helm
# ✓ helm.json wurde nach ../data/projects/helm/ verschoben
# Verarbeite: web-check
# ✓ web-check.json wurde nach ../data/projects/web-check/ verschoben
# Verarbeite: slint
# ✓ slint.json wurde nach ../data/projects/slint/ verschoben
# Verarbeite: spdlog
# ✓ spdlog.json wurde nach ../data/projects/spdlog/ verschoben
# Verarbeite: nuxt
# ✓ nuxt.json wurde nach ../data/projects/nuxt/ verschoben
# Verarbeite: vue2-elm
# ✓ vue2-elm.json wurde nach ../data/projects/vue2-elm/ verschoben
# Verarbeite: zx
# ✓ zx.json wurde nach ../data/projects/zx/ verschoben
# Verarbeite: cobra
# ✓ cobra.json wurde nach ../data/projects/cobra/ verschoben
# Verarbeite: robertdavidgraham_masscan
# ✓ robertdavidgraham_masscan.json wurde nach ../data/projects/robertdavidgraham_masscan/ verschoben
# Verarbeite: nginx
# ✓ nginx.json wurde nach ../data/projects/nginx/ verschoben
# Verarbeite: sweetalert2
# ✓ sweetalert2.json wurde nach ../data/projects/sweetalert2/ verschoben
# Verarbeite: agentic
# ✓ agentic.json wurde nach ../data/projects/agentic/ verschoben
# Verarbeite: Mobile-Security-Framework-MobSF
# ✓ Mobile-Security-Framework-MobSF.json wurde nach ../data/projects/Mobile-Security-Framework-MobSF/ verschoben
# Verarbeite: parse-server
# ✓ parse-server.json wurde nach ../data/projects/parse-server/ verschoben
# Verarbeite: colly
# ✓ colly.json wurde nach ../data/projects/colly/ verschoben
# Verarbeite: Perplexica
# ✓ Perplexica.json wurde nach ../data/projects/Perplexica/ verschoben
# Verarbeite: whisper.cpp
# ✓ whisper.cpp.json wurde nach ../data/projects/whisper.cpp/ verschoben
# Verarbeite: hackathon-starter
# ✓ hackathon-starter.json wurde nach ../data/projects/hackathon-starter/ verschoben
# Verarbeite: k9s
# ✓ k9s.json wurde nach ../data/projects/k9s/ verschoben
# Verarbeite: strapi_strapi
# ✓ strapi_strapi.json wurde nach ../data/projects/strapi_strapi/ verschoben
# Verarbeite: autogen
# ✓ autogen.json wurde nach ../data/projects/autogen/ verschoben
# Verarbeite: zustand
# ✓ zustand.json wurde nach ../data/projects/zustand/ verschoben
# Verarbeite: codemirror5
# ✓ codemirror5.json wurde nach ../data/projects/codemirror5/ verschoben
# Verarbeite: cherry-studio
# ✓ cherry-studio.json wurde nach ../data/projects/cherry-studio/ verschoben
# Verarbeite: powerlevel10k
# ✓ powerlevel10k.json wurde nach ../data/projects/powerlevel10k/ verschoben
# Verarbeite: go
# ✓ go.json wurde nach ../data/projects/go/ verschoben
# Verarbeite: firecracker
# ✓ firecracker.json wurde nach ../data/projects/firecracker/ verschoben
# Verarbeite: swiper
# ✓ swiper.json wurde nach ../data/projects/swiper/ verschoben
# Verarbeite: APIJSON
# ✓ APIJSON.json wurde nach ../data/projects/APIJSON/ verschoben
# Verarbeite: vim-airline
# ✓ vim-airline.json wurde nach ../data/projects/vim-airline/ verschoben
# Verarbeite: openvpn-install
# ✓ openvpn-install.json wurde nach ../data/projects/openvpn-install/ verschoben
# Verarbeite: validator
# ✓ validator.json wurde nach ../data/projects/validator/ verschoben
# Verarbeite: casbin
# ✓ casbin.json wurde nach ../data/projects/casbin/ verschoben
# Verarbeite: pyscript
# ✓ pyscript.json wurde nach ../data/projects/pyscript/ verschoben
# Verarbeite: git-extras
# ✓ git-extras.json wurde nach ../data/projects/git-extras/ verschoben
# Verarbeite: Dapper
# ✓ Dapper.json wurde nach ../data/projects/Dapper/ verschoben
# Verarbeite: cline
# ✓ cline.json wurde nach ../data/projects/cline/ verschoben
# Verarbeite: MMKV
# ✓ MMKV.json wurde nach ../data/projects/MMKV/ verschoben
# Verarbeite: fd
# ✓ fd.json wurde nach ../data/projects/fd/ verschoben
# Verarbeite: flash-attention
# ✓ flash-attention.json wurde nach ../data/projects/flash-attention/ verschoben
# Verarbeite: vapor
# ✓ vapor.json wurde nach ../data/projects/vapor/ verschoben
# Verarbeite: actual
# ✓ actual.json wurde nach ../data/projects/actual/ verschoben
# Verarbeite: pandas
# ✓ pandas.json wurde nach ../data/projects/pandas/ verschoben
# Verarbeite: eslint
# ✓ eslint.json wurde nach ../data/projects/eslint/ verschoben
# Verarbeite: commitlint
# ✓ commitlint.json wurde nach ../data/projects/commitlint/ verschoben
# Verarbeite: just
# ✓ just.json wurde nach ../data/projects/just/ verschoben
# Verarbeite: peft
# ✓ peft.json wurde nach ../data/projects/peft/ verschoben
# Verarbeite: microsoft_semantic-kernel
# ✓ microsoft_semantic-kernel.json wurde nach ../data/projects/microsoft_semantic-kernel/ verschoben
# Verarbeite: graphql
# ✓ graphql.json wurde nach ../data/projects/graphql/ verschoben
# Verarbeite: editor.js
# ✓ editor.js.json wurde nach ../data/projects/editor.js/ verschoben
# Verarbeite: LLMs-from-scratch
# ✓ LLMs-from-scratch.json wurde nach ../data/projects/LLMs-from-scratch/ verschoben
# Verarbeite: fuels-ts
# ✓ fuels-ts.json wurde nach ../data/projects/fuels-ts/ verschoben
# Verarbeite: solid
# ✓ solid.json wurde nach ../data/projects/solid/ verschoben
# Verarbeite: skywalking
# ✓ skywalking.json wurde nach ../data/projects/skywalking/ verschoben
# Verarbeite: floating-ui
# ✓ floating-ui.json wurde nach ../data/projects/floating-ui/ verschoben
# Verarbeite: libgdx
# ✓ libgdx.json wurde nach ../data/projects/libgdx/ verschoben
# Verarbeite: lexical
# ✓ lexical.json wurde nach ../data/projects/lexical/ verschoben
# Verarbeite: SnapKit
# ✓ SnapKit.json wurde nach ../data/projects/SnapKit/ verschoben
# Verarbeite: gogs
# ✓ gogs.json wurde nach ../data/projects/gogs/ verschoben
# Verarbeite: xbmc
# ✓ xbmc.json wurde nach ../data/projects/xbmc/ verschoben
# Verarbeite: LibreChat
# ✓ LibreChat.json wurde nach ../data/projects/LibreChat/ verschoben
# Verarbeite: frida
# ✓ frida.json wurde nach ../data/projects/frida/ verschoben
# Verarbeite: surya
# ✓ surya.json wurde nach ../data/projects/surya/ verschoben
# Verarbeite: jotai
# ✓ jotai.json wurde nach ../data/projects/jotai/ verschoben
# Verarbeite: ruby
# ✓ ruby.json wurde nach ../data/projects/ruby/ verschoben
# Verarbeite: go-kratos_kratos
# ✓ go-kratos_kratos.json wurde nach ../data/projects/go-kratos_kratos/ verschoben
# Verarbeite: relay
# ✓ relay.json wurde nach ../data/projects/relay/ verschoben
# Verarbeite: ai-hedge-fund
# ✓ ai-hedge-fund.json wurde nach ../data/projects/ai-hedge-fund/ verschoben
# Verarbeite: headscale
# ✓ headscale.json wurde nach ../data/projects/headscale/ verschoben
# Verarbeite: termux-app
# ✓ termux-app.json wurde nach ../data/projects/termux-app/ verschoben
# Verarbeite: compose-multiplatform
# ✓ compose-multiplatform.json wurde nach ../data/projects/compose-multiplatform/ verschoben
# Verarbeite: tensorflow
# ✓ tensorflow.json wurde nach ../data/projects/tensorflow/ verschoben
# Verarbeite: ghostty
# ✓ ghostty.json wurde nach ../data/projects/ghostty/ verschoben
# Verarbeite: delve
# ✓ delve.json wurde nach ../data/projects/delve/ verschoben
# Verarbeite: vaultwarden
# ✓ vaultwarden.json wurde nach ../data/projects/vaultwarden/ verschoben
# Verarbeite: Docker-OSX
# ✓ Docker-OSX.json wurde nach ../data/projects/Docker-OSX/ verschoben
# Verarbeite: MiniCPM-o
# ✓ MiniCPM-o.json wurde nach ../data/projects/MiniCPM-o/ verschoben
# Verarbeite: cloudreve
# ✓ cloudreve.json wurde nach ../data/projects/cloudreve/ verschoben
# Verarbeite: Flowise
# ✓ Flowise.json wurde nach ../data/projects/Flowise/ verschoben
# Verarbeite: osquery
# ✓ osquery.json wurde nach ../data/projects/osquery/ verschoben
# Verarbeite: llama.cpp
# ✓ llama.cpp.json wurde nach ../data/projects/llama.cpp/ verschoben
# Verarbeite: memos
# ✓ memos.json wurde nach ../data/projects/memos/ verschoben
# Verarbeite: v2rayNG
# ✓ v2rayNG.json wurde nach ../data/projects/v2rayNG/ verschoben
# Verarbeite: etcd
# ✓ etcd.json wurde nach ../data/projects/etcd/ verschoben
# Verarbeite: teable
# ✓ teable.json wurde nach ../data/projects/teable/ verschoben
# Verarbeite: electron_electron
# ✓ electron_electron.json wurde nach ../data/projects/electron_electron/ verschoben
# Verarbeite: frigate
# ✓ frigate.json wurde nach ../data/projects/frigate/ verschoben
# Verarbeite: timqian_chinese-independent-blogs
# ✓ timqian_chinese-independent-blogs.json wurde nach ../data/projects/timqian_chinese-independent-blogs/ verschoben
# Verarbeite: classnames
# ✓ classnames.json wurde nach ../data/projects/classnames/ verschoben
# Verarbeite: AgentGPT
# ✓ AgentGPT.json wurde nach ../data/projects/AgentGPT/ verschoben
# Verarbeite: authelia
# ✓ authelia.json wurde nach ../data/projects/authelia/ verschoben
# Verarbeite: open-interpreter
# ✓ open-interpreter.json wurde nach ../data/projects/open-interpreter/ verschoben
# Verarbeite: brave-browser
# ✓ brave-browser.json wurde nach ../data/projects/brave-browser/ verschoben
# Verarbeite: ntfy
# ✓ ntfy.json wurde nach ../data/projects/ntfy/ verschoben
# Verarbeite: postiz-app
# ✓ postiz-app.json wurde nach ../data/projects/postiz-app/ verschoben
# Verarbeite: vue-admin-better
# ✓ vue-admin-better.json wurde nach ../data/projects/vue-admin-better/ verschoben
# Verarbeite: Scrapegraph-ai
# ✓ Scrapegraph-ai.json wurde nach ../data/projects/Scrapegraph-ai/ verschoben
# Verarbeite: ignite
# ✓ ignite.json wurde nach ../data/projects/ignite/ verschoben
# Verarbeite: setup
# ✓ setup.json wurde nach ../data/projects/setup/ verschoben
# Verarbeite: druid
# ✓ druid.json wurde nach ../data/projects/druid/ verschoben
# Verarbeite: open-webui
# ✓ open-webui.json wurde nach ../data/projects/open-webui/ verschoben
# Verarbeite: fabric.js
# ✓ fabric.js.json wurde nach ../data/projects/fabric.js/ verschoben
# Verarbeite: locust
# ✓ locust.json wurde nach ../data/projects/locust/ verschoben
# Verarbeite: nacos
# ✓ nacos.json wurde nach ../data/projects/nacos/ verschoben
# Verarbeite: cheerio
# ✓ cheerio.json wurde nach ../data/projects/cheerio/ verschoben
# Verarbeite: dotenv
# ✓ dotenv.json wurde nach ../data/projects/dotenv/ verschoben
# Fertig!

# %%
import os
import shutil

# Quell- und Zielverzeichnisse
source_dir = "../data/projects_with_batches/"
target_dir = "../data/projects/"

# Stelle sicher, dass das Zielverzeichnis existiert
os.makedirs(target_dir, exist_ok=True)

# Liste aller Ordner im Quellverzeichnis
folders = [f for f in os.listdir(source_dir) if os.path.isdir(os.path.join(source_dir, f))]

print(f"Gefundene Ordner: {len(folders)}")

for folder_name in folders:
    source_path = os.path.join(source_dir, folder_name)
    target_path = os.path.join(target_dir, folder_name)
    
    print(f"Verschiebe: {folder_name}")
    
    try:
        # Prüfe, ob der Zielordner bereits existiert
        if os.path.exists(target_path):
            print(f"⚠️ Ordner {folder_name} existiert bereits in {target_dir}, überspringe.")
            continue
        
        # Verschiebe den gesamten Ordner
        shutil.move(source_path, target_path)
        
        print(f"✓ {folder_name} wurde erfolgreich nach {target_dir} verschoben")
        
    except Exception as e:
        print(f"✗ Fehler beim Verschieben von {folder_name}: {e}")

print("Fertig!")
# Out:
# Gefundene Ordner: 5
# Verschiebe: servo_servo
# ⚠️ Ordner servo_servo existiert bereits in ../data/projects/, überspringe.
# Verschiebe: invoke-ai_InvokeAI
# ⚠️ Ordner invoke-ai_InvokeAI existiert bereits in ../data/projects/, überspringe.
# Verschiebe: netdata_netdata
# ⚠️ Ordner netdata_netdata existiert bereits in ../data/projects/, überspringe.
# Verschiebe: continuedev_continue
# ⚠️ Ordner continuedev_continue existiert bereits in ../data/projects/, überspringe.
# Verschiebe: strapi_strapi
# ⚠️ Ordner strapi_strapi existiert bereits in ../data/projects/, überspringe.
# Fertig!
